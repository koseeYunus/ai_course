# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df=pd.DataFrame({
    'color':['green','red','blue'],
    'size':['small','medium','large'],
    'classlabel':['yes','no','yes'],
    'price':[10.1,12.2,14.]
})

# %%
df
# Out:
#    color    size classlabel  price
# 0  green   small        yes   10.1
# 1    red  medium         no   12.2
# 2   blue   large        yes   14.0

# %%
le=LabelEncoder()

# %%
df['size2']=le.fit_transform(df['size'])

# %%
df
# Out:
#    color    size classlabel  price  size2
# 0  green   small        yes   10.1      2
# 1    red  medium         no   12.2      1
# 2   blue   large        yes   14.0      0

# %%
ohe=OneHotEncoder()

# %%
ohe.fit_transform(df[['color']]).toarray()
# Out:
# array([[0., 1., 0.],
#        [0., 0., 1.],
#        [1., 0., 0.]])

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#    price  size2  color_green  color_red  size_medium  size_small  \
# 0   10.1      2         True      False        False        True
# 1   12.2      1        False       True         True       False
# 2   14.0      0        False      False        False       False
#
#    classlabel_yes
# 0            True
# 1           False
# 2            True

# %%
# pip install gensim

# %%
# pip install spacy

# %%
cumleler= [['Hello','This','is','python','training','by','Aman'],
             ['Hello','This','is','Java','training','by','Aman'],
             ['Hello','This','is','Data Science','training','by','Unfold','Data','Science'],
             ['Hello','This','is','programming','training','']]

# %%
from gensim.models import Word2Vec

# %%
model=Word2Vec(cumleler, min_count=1)

# %%
words = list(model.wv.key_to_index)

# %%
words
# Out:
# ['training',
#  'is',
#  'This',
#  'Hello',
#  'by',
#  'Aman',
#  '',
#  'programming',
#  'Science',
#  'Data',
#  'Unfold',
#  'Data Science',
#  'Java',
#  'python']

# %%
model.wv['Hello']
# Out:
# array([-8.2426779e-03,  9.2993546e-03, -1.9766092e-04, -1.9672764e-03,
#         4.6036304e-03, -4.0953159e-03,  2.7431143e-03,  6.9399667e-03,
#         6.0654259e-03, -7.5107943e-03,  9.3823504e-03,  4.6718083e-03,
#         3.9661205e-03, -6.2435055e-03,  8.4599797e-03, -2.1501649e-03,
#         8.8251876e-03, -5.3620026e-03, -8.1294188e-03,  6.8245591e-03,
#         1.6711927e-03, -2.1985089e-03,  9.5136007e-03,  9.4938548e-03,
#        -9.7740470e-03,  2.5052286e-03,  6.1566923e-03,  3.8724565e-03,
#         2.0227872e-03,  4.3050171e-04,  6.7363144e-04, -3.8206363e-03,
#        -7.1402504e-03, -2.0888723e-03,  3.9238976e-03,  8.8186832e-03,
#         9.2591504e-03, -5.9759365e-03, -9.4026709e-03,  9.7643770e-03,
#         3.4297847e-03,  5.1661171e-03,  6.2823449e-03, -2.8042626e-03,
#         7.3227035e-03,  2.8302716e-03,  2.8710044e-03, -2.3803699e-03,
#        -3.1282497e-03, -2.3701417e-03,  4.2764368e-03,  7.6057913e-05,
#        -9.5842788e-03, -9.6655441e-03, -6.1481940e-03, -1.2856961e-04,
#         1.9974159e-03,  9.4319675e-03,  5.5843508e-03, -4.2906962e-03,
#         2.7831673e-04,  4.9643586e-03,  7.6983096e-03, -1.1442233e-03,
#         4.3234206e-03, -5.8143795e-03, -8.0419064e-04,  8.1000505e-03,
#        -2.3600650e-03, -9.6634552e-03,  5.7792603e-03, -3.9298222e-03,
#        -1.2228728e-03,  9.9805174e-03, -2.2563506e-03, -4.7570644e-03,
#        -5.3293873e-03,  6.9808899e-03, -5.7088719e-03,  2.1136629e-03,
#        -5.2556600e-03,  6.1207139e-03,  4.3573068e-03,  2.6063549e-03,
#        -1.4910829e-03, -2.7460635e-03,  8.9929365e-03,  5.2157748e-03,
#        -2.1625196e-03, -9.4703101e-03, -7.4260519e-03, -1.0637414e-03,
#        -7.9494715e-04, -2.5629092e-03,  9.6827205e-03, -4.5852066e-04,
#         5.8737611e-03, -7.4475873e-03, -2.5060738e-03, -5.5498634e-03],
#       dtype=float32)

# %%
# Cosine Similarity

# %%
model.wv.similarity('Hello','This')
# Out:
# np.float32(-0.013514926)

# %%
# LDA = Latent Drichlet Allocation - Topic modelin - Hangi konuda konusuldugunu anlama

# %%
import gensim
from gensim import corpora
from gensim.models import LdaModel

# Sample documents
documents = [
    "Tennis is my favorite sport to play.",
    "Football is a popular competition in certain country.",
    "There are many athletes currently training for the olympic."
]

# Preprocess documents
texts = [[word for word in document.lower().split()] for document in documents]

dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]


#The LDA model
lda_model = LdaModel(corpus, num_topics=2, id2word=dictionary, passes=15)

topics = lda_model.print_topics()
for topic in topics:
    print(topic)
# Out:
# (0, '0.082*"is" + 0.081*"my" + 0.081*"play." + 0.081*"sport" + 0.081*"to" + 0.081*"tennis" + 0.081*"favorite" + 0.027*"in" + 0.027*"popular" + 0.027*"country."')
# (1, '0.053*"currently" + 0.053*"the" + 0.053*"are" + 0.053*"many" + 0.053*"olympic." + 0.053*"there" + 0.053*"athletes" + 0.053*"training" + 0.053*"for" + 0.053*"certain"')

# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup
import gensim
from gensim import corpora
from gensim.models import LdaModel

# Function to scrape transcript data
def url_to_transcript(url):
    '''Returns transcript text specifically from scrapsfromtheloft.com.'''
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    text = [p.text for p in soup.find(class_="ast-container").find_all('p')]
    print(f'Successfully scraped: {url}')
    return ' '.join(text)

# URLs of transcripts
urls = [
    'http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/',
    'http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/',
    'http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/',
    'https://scrapsfromtheloft.com/comedy/bo-burnham-what-transcript/',
    'http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/',
    'http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/',
    'http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/',
    'https://scrapsfromtheloft.com/comedy/hasan-minhaj-homecoming-king-transcript/',
    'http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/',
    'http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/',
    'http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/',
    'http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/'
]

# Comedian names (for reference)
comedians = ['louis', 'dave', 'ricky', 'bo', 'bill', 'jim', 'john', 'hasan', 'ali', 'anthony', 'mike', 'joe']

# Scrape transcripts
documents = [url_to_transcript(url) for url in urls]

# Preprocess the transcripts for LDA modeling
texts = [
    gensim.utils.simple_preprocess(doc, deacc=True)  # removes punctuations and accents
    for doc in documents
]

# Create dictionary and corpus
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# LDA Model setup
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15, random_state=42)

# Print the topics
topics = lda_model.print_topics(num_words=10)
print("\nTopics discovered in comedians' transcripts:")
for idx, topic in topics:
    print(f"Topic #{idx + 1}: {topic}\n")
# Out:
# Successfully scraped: http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/
# Successfully scraped: https://scrapsfromtheloft.com/comedy/bo-burnham-what-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/
# Successfully scraped: https://scrapsfromtheloft.com/comedy/hasan-minhaj-homecoming-king-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/
#
# Topics discovered in comedians' transcripts:
# Topic #1: 0.038*"and" + 0.032*"the" + 0.031*"you" + 0.022*"to" + 0.020*"it" + 0.019*"that" + 0.016*"of" + 0.015*"in" + 0.014*"like" + 0.011*"my"
#
# Topic #2: 0.034*"you" + 0.024*"the" + 0.019*"voice" + 0.017*"to" + 0.017*"and" + 0.014*"it" + 0.012*"that" + 0.010*"of" + 0.009*"is" + 0.008*"my"
#
# Topic #3: 0.036*"and" + 0.029*"the" + 0.027*"you" + 0.021*"to" + 0.020*"that" + 0.018*"like" + 0.016*"it" + 0.014*"of" + 0.013*"my" + 0.012*"was"
#
# Topic #4: 0.001*"you" + 0.001*"and" + 0.001*"the" + 0.001*"it" + 0.001*"to" + 0.001*"that" + 0.000*"of" + 0.000*"like" + 0.000*"in" + 0.000*"my"
#
# Topic #5: 0.034*"the" + 0.032*"you" + 0.023*"and" + 0.021*"to" + 0.021*"that" + 0.020*"it" + 0.015*"like" + 0.014*"in" + 0.013*"of" + 0.011*"was"

# %%
# pip install nltk

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
# Imports
import requests
from bs4 import BeautifulSoup
import pandas as pd
import gensim
from gensim import corpora
from gensim.models.ldamulticore import LdaMulticore
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import text
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# Scrape function
def url_to_transcript(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    paragraphs = soup.find(class_="ast-container").find_all('p')
    text_data = ' '.join(p.text for p in paragraphs)
    print(f'Successfully scraped: {url}')
    return text_data

# Custom stopwords
add_stop_words = [
    'like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people', 'youre', 'got',
    'gonna', 'time', 'think', 'yeah', 'said', 'want', 'say', 'thing', 'going', 'shit',
    'fucking', 'didnt', 'hes', 'shes', 'theyre', 'weve', 'ill', 'youve', 'ive', 'couldnt',
    'wouldnt', 'cant', 'wont', 'one', 'get', 'really', 'see', '♪', 'g', 'okay'
]

# Convert frozenset to list for CountVectorizer
stop_words = list(text.ENGLISH_STOP_WORDS.union(add_stop_words))


# Lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to extract only nouns and adjectives
def nouns_adj(text):
    text = text.lower()
    text = re.sub(r"’", "'", text)
    text = re.sub(r"[^a-zA-Z']", " ", text)
    text = re.sub(r'\s+', ' ', text)
    tokenized = word_tokenize(text)
    tagged = pos_tag(tokenized)
    is_noun_adj = lambda pos: pos.startswith('NN') or pos.startswith('JJ')
    words = [lemmatizer.lemmatize(word) for word, pos in tagged if is_noun_adj(pos) and word not in stop_words]
    return ' '.join(words)

# URLs and comedian names
urls = [
    'http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/',
    'http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/',
    'http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/',
    'https://scrapsfromtheloft.com/comedy/bo-burnham-what-transcript/',
    'http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/',
    'http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/',
    'http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/',
    'https://scrapsfromtheloft.com/comedy/hasan-minhaj-homecoming-king-transcript/',
    'http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/',
    'http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/',
    'http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/',
    'http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/'
]

comedians = ['Louis CK', 'Dave Chappelle', 'Ricky Gervais', 'Bo Burnham', 'Bill Burr',
             'Jim Jefferies', 'John Mulaney', 'Hasan Minhaj', 'Ali Wong',
             'Anthony Jeselnik', 'Mike Birbiglia', 'Joe Rogan']

# Scrape and clean
documents = [url_to_transcript(url) for url in urls]
cleaned_docs = [nouns_adj(doc) for doc in documents]

# Build CountVectorizer
cv = CountVectorizer(stop_words=stop_words, max_df=0.8)
data_cv = cv.fit_transform(cleaned_docs)

# Convert into pandas DataFrame for gensim
dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())

# Create corpus for LDA
corpus = gensim.matutils.Sparse2Corpus(data_cv, documents_columns=False)
id2word = dict((id, word) for word, id in cv.vocabulary_.items())

# LDA Model (12 topics for 12 comedians)
lda_model = LdaMulticore(corpus, num_topics=12, id2word=id2word, passes=50, workers=2, random_state=42)

# Show topics
topics = lda_model.print_topics(num_words=10)
for idx, topic in topics:
    print(f"\n📝 Topic {idx}:\n{topic}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Successfully scraped: http://scrapsfromtheloft.com/2017/05/06/louis-ck-oh-my-god-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/04/11/dave-chappelle-age-spin-2017-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2018/03/15/ricky-gervais-humanity-transcript/
# Successfully scraped: https://scrapsfromtheloft.com/comedy/bo-burnham-what-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/05/24/bill-burr-im-sorry-feel-way-2014-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/04/21/jim-jefferies-bare-2014-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/08/02/john-mulaney-comeback-kid-2015-full-transcript/
# Successfully scraped: https://scrapsfromtheloft.com/comedy/hasan-minhaj-homecoming-king-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/09/19/ali-wong-baby-cobra-2016-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/08/03/anthony-jeselnik-thoughts-prayers-2015-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2018/03/03/mike-birbiglia-my-girlfriends-boyfriend-2013-full-transcript/
# Successfully scraped: http://scrapsfromtheloft.com/2017/08/19/joe-rogan-triggered-2016-full-transcript/
#
# 📝 Topic 0:
# 0.000*"voice" + 0.000*"fuck" + 0.000*"gun" + 0.000*"parent" + 0.000*"audience" + 0.000*"ah" + 0.000*"laughter" + 0.000*"let" + 0.000*"door" + 0.000*"ok"
#
# 📝 Topic 1:
# 0.012*"nut" + 0.009*"chimp" + 0.008*"jenner" + 0.007*"hampstead" + 0.007*"rape" + 0.007*"twitter" + 0.006*"bob" + 0.006*"jane" + 0.006*"dog" + 0.006*"dead"
#
# 📝 Topic 2:
# 0.000*"voice" + 0.000*"fuck" + 0.000*"audience" + 0.000*"ah" + 0.000*"bro" + 0.000*"gun" + 0.000*"bo" + 0.000*"dog" + 0.000*"american" + 0.000*"repeat"
#
# 📝 Topic 3:
# 0.010*"fuck" + 0.007*"tit" + 0.006*"ok" + 0.006*"gun" + 0.005*"anthony" + 0.005*"shark" + 0.005*"half" + 0.004*"dead" + 0.004*"husband" + 0.004*"somebody"
#
# 📝 Topic 4:
# 0.018*"clinton" + 0.012*"cow" + 0.010*"wife" + 0.008*"parent" + 0.007*"president" + 0.007*"john" + 0.006*"ballroom" + 0.006*"finch" + 0.006*"petunia" + 0.005*"office"
#
# 📝 Topic 5:
# 0.027*"ck" + 0.008*"cking" + 0.007*"stupid" + 0.007*"dolphin" + 0.005*"audience" + 0.005*"texas" + 0.005*"earth" + 0.005*"religion" + 0.005*"mar" + 0.005*"debbie"
#
# 📝 Topic 6:
# 0.018*"jenny" + 0.008*"andy" + 0.008*"accident" + 0.007*"marriage" + 0.007*"scrambler" + 0.006*"argument" + 0.006*"club" + 0.005*"parent" + 0.005*"idea" + 0.005*"morning"
#
# 📝 Topic 7:
# 0.000*"ah" + 0.000*"fuck" + 0.000*"ck" + 0.000*"gun" + 0.000*"voice" + 0.000*"audience" + 0.000*"gay" + 0.000*"door" + 0.000*"american" + 0.000*"wife"
#
# 📝 Topic 8:
# 0.000*"voice" + 0.000*"jenny" + 0.000*"andy" + 0.000*"fuck" + 0.000*"parent" + 0.000*"party" + 0.000*"mad" + 0.000*"door" + 0.000*"anthony" + 0.000*"accident"
#
# 📝 Topic 9:
# 0.015*"ah" + 0.013*"fuck" + 0.009*"gun" + 0.007*"american" + 0.007*"audience" + 0.006*"laughter" + 0.006*"son" + 0.006*"hasan" + 0.005*"girlfriend" + 0.004*"cunt"
#
# 📝 Topic 10:
# 0.081*"voice" + 0.019*"bo" + 0.019*"bro" + 0.017*"robotic" + 0.015*"repeat" + 0.011*"contact" + 0.010*"laughter" + 0.010*"slut" + 0.009*"song" + 0.009*"music"
#
# 📝 Topic 11:
# 0.000*"fuck" + 0.000*"gun" + 0.000*"son" + 0.000*"parent" + 0.000*"ah" + 0.000*"let" + 0.000*"audience" + 0.000*"father" + 0.000*"american" + 0.000*"dog"

# %%
# NER Named Entity Recognition

# %%
import spacy

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 25.3 MB/s eta 0:00:00
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp=spacy.load(name='en_core_web_md')

# %%
doc=nlp('Jonathan is looking for a job in Turkey for 50k. Word Healt Organization WHO')

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Jonathan Jonathan PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# for for ADP IN prep xxx True True
# a a DET DT det x True True
# job job NOUN NN pobj xxx True False
# in in ADP IN prep xx True True
# Turkey Turkey PROPN NNP pobj Xxxxx True False
# for for ADP IN prep xxx True True
# 50k 50k NUM CD pobj ddx False False
# . . PUNCT . punct . False False
# Word Word PROPN NNP compound Xxxx True False
# Healt Healt PROPN NNP compound Xxxxx True False
# Organization Organization PROPN NNP ROOT Xxxxx True False
# WHO who PRON WP ROOT XXX True True

# %%
from spacy import displacy

# %%
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ccd2d55b7f844bfe99853be075abece5-0" class="displacy" width="2500" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Jonathan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">job</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Turkey</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">50k.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Word</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Healt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Organization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">WHO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-5" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1090.0,266.5 L1098.0,254.5 1082.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ccd2d55b7f844bfe99853be075abece5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,266.5 L1273.0,254.5 1257.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ccd2d55b7f844bfe99853be075abece5-0-7" stroke-width="2p

# %%
text = '''When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously.
He immigrated in 2003. Zafer loves NLP'''
doc = nlp(text)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him seriously. <br>He immigrated in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zafer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %% [markdown]
# # Titanic Prework

# %% [markdown]
# ### Projenin Amaci

# %% [markdown]
# Proje, Titanic yolcu verileri kullanarak bir sınıflandırma modeli oluşturmayı hedefliyor. Amaç, yolcuların hayatta kalma durumunu tahmin etmektir.

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from yellowbrick.classifier import ROCAUC
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv('ttrain.csv')
test_df = pd.read_csv('ttest.csv')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 755          756         1       2          Hamalainen, Master. Viljo  male
# 408          409         0       3  Birkeland, Mr. Hans Martin Monsen  male
#
#        Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 755   0.67      1      1  250649  14.500   NaN        S
# 408  21.00      0      0  312992   7.775   NaN        S

# %%
test_df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
test_df.sample(4)
# Out:
#      PassengerId  Pclass                                          Name  \
# 18           910       3                  Ilmakangas, Miss. Ida Livija
# 228         1120       3                     Everett, Mr. Thomas James
# 306         1198       1          Allison, Mr. Hudson Joshua Creighton
# 405         1297       2  Nourney, Mr. Alfred (Baron von Drachstedt")"
#
#         Sex   Age  SibSp  Parch            Ticket      Fare    Cabin Embarked
# 18   female  27.0      1      0  STON/O2. 3101270    7.9250      NaN        S
# 228    male  40.5      0      0         C.A. 6212   15.1000      NaN        S
# 306    male  30.0      1      2            113781  151.5500  C22 C26        S
# 405    male  20.0      0      0     SC/PARIS 2166   13.8625      D38        C

# %% [markdown]
# ### EDA - Exploratory Data Analysis

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Age, Cabin, ve Embarked sütunlarında eksik veriler var.

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Age, Fare, ve Cabin sütunlarında eksik veriler var.

# %%
test_df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## Eksik Verilerin Doldurulması veya Tamamen Silinmesi

# %%
# Train set için eksik değerleri doldur
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
train_df.drop('Cabin', axis=1, inplace=True) # cok fazla bos veri oldugu icin ve pek anlama ifade etemdigi siliyoruz
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
# Test set için eksik değerleri doldur
test_df['Age'].fillna(test_df['Age'].median(), inplace=True)
test_df.drop('Cabin', axis=1, inplace=True) # cok fazla bos veri oldugu icin ve pek anlama ifade etemdigi siliyoruz
test_df['Fare'].fillna(test_df['Fare'].median(), inplace=True)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 32.8+ KB

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %% [markdown]
# ## Kategorik Sütunları Sayısala Çevirme

# %%
# Sex ve Embarked sütunlarını sayısal verilere dönüştürelim

# %%
train_df['Sex'] = train_df['Sex'].map({'male': 0, 'female': 1})
train_df['Embarked'] = train_df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

test_df['Sex'] = test_df['Sex'].map({'male': 0, 'female': 1})
test_df['Embarked'] = test_df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
# ...

# %% [markdown]
# ## Feature Engineering

# %%
# Aile büyüklüğünü temsil eden bir FamilySize sütunu ekleyelim

# %%
train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1
test_df['FamilySize'] = test_df['SibSp'] + test_df['Parch'] + 1

# %% [markdown]
# ## Veriyi X ve y Olarak Ayırma

# %%
# Hedef değişken olan Survived sütununu ayıralım

# %%
x_train = train_df.drop(['Survived', 'Name', 'Ticket'], axis=1)
y_train = train_df['Survived']
x_test = test_df.drop(['Name', 'Ticket'], axis=1)

# %% [markdown]
# ## Model Eğitimi ve Tahmin

# %%
# Model eğitebilir ve tahmin edilebilir

# %%
x_train_split, x_valid, y_train_split, y_valid = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
rmodel = RandomForestClassifier()

# %%
rmodel.fit(x_train_split, y_train_split)
# Out:
# RandomForestClassifier()

# %%
y_pred = rmodel.predict(x_valid)

# %%
accuracy_score(y_valid, y_pred)
# Out:
# 0.8324022346368715

# %%
print(confusion_matrix(y_valid, y_pred))
# Out:
# [[92 13]
#  [17 57]]

# %%
print(classification_report(y_valid, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       105
#            1       0.81      0.77      0.79        74
#
#     accuracy                           0.83       179
#    macro avg       0.83      0.82      0.83       179
# weighted avg       0.83      0.83      0.83       179

# %%
visualizer = ROCAUC(rmodel, classes=["Not Survived", "Survived"])
visualizer.fit(x_train_split, y_train_split)
visualizer.score(x_valid, y_valid)
visualizer.show();
